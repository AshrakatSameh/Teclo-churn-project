# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  6616-AALSR  Female              0     Yes        Yes      65          Yes
# 2  6625-UTXEW  Female              0     Yes         No      12          Yes
# 3  6625-IUTTT    Male              0      No         No      67          Yes
# 4  6625-FLENO    Male              0     Yes         No      58          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No             DSL                   No  ...
# 1           Yes     Fiber optic                  Yes  ...
# 2            No             DSL                   No  ...
# 3            No             DSL                  Yes  ...
# 4            No              No  No internet service  ...
#
#            TechSupport          StreamingTV      StreamingMovies  \
# 0                  Yes                  Yes                   No
# ...

# %% [markdown]
# # EDA And Visualization

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn', '0'],
#       dtype='object')

# %%
df.drop(columns= '0', axis= 1, inplace=True)

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
for i in df:
    print(f'{df[i].value_counts()}')
# Out:
# 0002-ORFBO    1
# 0019-EFAEP    1
# 0011-IGKFF    1
# 0013-EXCHZ    1
# 0013-MHZWF    1
#              ..
# 9992-RRAMN    1
# 9992-UJOEL    1
# 9993-LHIEB    1
# 9958-MEKUC    1
# 9995-HOTOH    1
# Name: customerID, Length: 7043, dtype: int64
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
# No                     3498
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %%
df.describe(include= 'O').T
# Out:
#                  count unique               top  freq
# customerID        7043   7043        0002-ORFBO     1
# gender            7043      2              Male  3555
# Partner           7043      2                No  3641
# Dependents        7043      2                No  4933
# PhoneService      7043      2               Yes  6361
# MultipleLines     7043      3                No  3390
# InternetService   7043      3       Fiber optic  3096
# OnlineSecurity    7043      3                No  3498
# OnlineBackup      7043      3                No  3088
# DeviceProtection  7043      3                No  3095
# TechSupport       7043      3                No  3473
# StreamingTV       7043      3                No  2810
# StreamingMovies   7043      3                No  2785
# Contract          7043      3    Month-to-month  3875
# PaperlessBilling  7043      2               Yes  4171
# PaymentMethod     7043      4  Electronic check  2365
# ...

# %%
df['TotalCharges']= pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
sns.displot(data= df, x='MonthlyCharges', col='Churn', kde= True)

# %%
sns.displot(data= df, x='TotalCharges', col='Churn', kde= True)

# %%
sns.displot(data= df, x='tenure', col='Contract', kde= True)

# %%
sns.countplot(data=df, x= 'Contract', hue='Churn')
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
sns.countplot(data =df, x= 'gender', hue='Churn')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(data =df, x= 'InternetService', hue= 'Churn')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
sns.countplot(data =df, x= 'MultipleLines', hue= 'Churn')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(data =df, x= 'TechSupport', hue= 'Churn')
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='count'>

# %%
sns.countplot(data =df, x= 'StreamingTV', hue= 'Churn')
# Out:
# <AxesSubplot:xlabel='StreamingTV', ylabel='count'>

# %%
sns.countplot(data =df, x= 'StreamingMovies', hue= 'Churn')
# Out:
# <AxesSubplot:xlabel='StreamingMovies', ylabel='count'>

# %%
sns.countplot(data =df, x= 'PaymentMethod', hue= 'Churn')
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='count'>

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
df[df['TotalCharges'].isna()]['TotalCharges']
# Out:
# 1586   NaN
# 3069   NaN
# 3760   NaN
# 4075   NaN
# 5396   NaN
# 5647   NaN
# 6045   NaN
# 6257   NaN
# 6326   NaN
# 6596   NaN
# 6912   NaN
# Name: TotalCharges, dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
for i in df:
    print(i,  df[i].nunique(), "\n", df[i].unique())
# Out:
# customerID 7032
#  ['0002-ORFBO' '6616-AALSR' '6625-UTXEW' ... '3351-NQLDI' '3351-NGXYI'
#  '9995-HOTOH']
# gender 2
#  ['Female' 'Male']
# SeniorCitizen 2
#  [0 1]
# Partner 2
#  ['Yes' 'No']
# Dependents 2
#  ['Yes' 'No']
# tenure 72
#  [ 9 65 12 67 58  6  5 63 18 24 45  1 23 14 61 71 72 30 33 46 47 59  2 39
#  16 48 50 11 49  4 53 62 34 28 13 60 51  3 15 35 69 26 25 17 70 27 32 42
#  31 56 52 19 44 57 40 29 68 10 38 66 36 20 43  7 22  8 54 64 37 55 41 21]
# PhoneService 2
#  ['Yes' 'No']
# MultipleLines 3
#  ['No' 'Yes' 'No phone service']
# InternetService 3
#  ['DSL' 'Fiber optic' 'No']
# OnlineSecurity 3
#  ['No' 'Yes' 'No internet service']
# OnlineBackup 3
#  ['Yes' 'No' 'No internet service']
# DeviceProtection 3
#  ['No' 'Yes' 'No internet service']
# TechSupport 3
#  ['Yes' 'No' 'No internet service']
# StreamingTV 3
#  ['Yes' 'No' 'No internet service']
# StreamingMovies 3
#  ['No' 'Yes' 'No internet service']
# Contract 3
#  ['One year' 'Two year' 'Month-to-month']
# ...

# %%
df['gender']= df['gender'].map({'Male':1 , 'Female':0})

# %%
from sklearn.preprocessing import LabelEncoder
LEncoder= LabelEncoder()
df['Partner'] = LEncoder.fit_transform(df['Partner']) 
df['Dependents'] = LEncoder.fit_transform(df['Dependents'])
df['PhoneService'] = LEncoder.fit_transform(df['PhoneService'])
df['PaperlessBilling'] = LEncoder.fit_transform(df['PaperlessBilling'])

# %%
colms_OneHot= ['Contract', 'PaymentMethod', 'MultipleLines', 'InternetService',
              'OnlineSecurity','OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies']

df= pd.get_dummies(df, columns=colms_OneHot )

# %%
df= pd.get_dummies(df, columns=['Churn'], drop_first=True)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO       0              0        1           1       9
# 1  6616-AALSR       0              0        1           1      65
# 2  6625-UTXEW       0              0        1           0      12
# 3  6625-IUTTT       1              0        0           0      67
# 4  6625-FLENO       1              0        1           0      58
#
#    PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  ...  \
# 0             1                 1           65.60        593.30  ...
# 1             1                 1          104.30       6725.30  ...
# 2             1                 1           51.25        612.10  ...
# 3             1                 0           65.55       4361.55  ...
# 4             1                 0           20.75       1185.95  ...
#
#    TechSupport_No  TechSupport_No internet service  TechSupport_Yes  \
# 0               0                                0                1
# ...

# %%
df.drop(columns='customerID', axis= 1, inplace= True)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No',
# ...

# %% [markdown]
# # Modeling

# %%
x = df.drop('Churn_Yes', axis=1)
y = df['Churn_Yes']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2)

# %%
 x_train.shape , x_test.shape
# Out:
# ((5625, 40), (1407, 40))

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#colms= ['tenure', 'MonthlyCharges', 'TotalCharges']
#df[colms]= scaler.fit_transform(df[colms])
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train= scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, fbeta_score, classification_report

# %%
models = {
    "LR": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "SVC": SVC(kernel='sigmoid'),
    "DT": DecisionTreeClassifier(max_depth=5, min_samples_split=4),
    "RF": RandomForestClassifier(n_estimators=100),
    "XGB": XGBClassifier(n_estimators=70),
    "Naive Bayes": GaussianNB()
}

# %%
for name, model in models.items():
    print(f'Training Model {name} \n--------------')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Training Accuracy: {model.score(x_train, y_train)}')
    print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
    print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
    print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
    print(f'Testing F-1: {f1_score(y_test, y_pred)}')
    print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
    print('-'*30)
# Out:
# Training Model LR
# --------------
# Training Accuracy: 0.8019555555555555
# Testing Accuracy: 0.8230277185501066
# Testing Confusion Matrix:
# [[956 106]
#  [143 202]]
# Testing Recall: 0.5855072463768116
# Testing Precesion: 0.6558441558441559
# Testing F-1: 0.6186830015313937
# Testing F-Beta: 0.6404565630944832
# ------------------------------
# Training Model KNN
# --------------
# Training Accuracy: 0.8291555555555555
# Testing Accuracy: 0.7839374555792467
# Testing Confusion Matrix:
# [[913 149]
#  [155 190]]
# Testing Recall: 0.5507246376811594
# Testing Precesion: 0.56047197640118
# Testing F-1: 0.5555555555555557
# Testing F-Beta: 0.5584950029394474
# ------------------------------
# Training Model SVC
# --------------
# Training Accuracy: 0.7264
# Testing Accuracy: 0.7476901208244492
# Testing Confusion Matrix:
# [[874 188]
#  [167 178]]
# Testing Recall: 0.5159420289855072
# Testing Precesion: 0.48633879781420764
# Testing F-1: 0.5007032348804501
# ...

# %% [markdown]
# # KNN Classifier model

# %%
KNN= KNeighborsClassifier(n_neighbors= 5)
KNN.fit(x_train, y_train)
y_pred = KNN.predict(x_test)
print(f'Training Accuracy: {KNN.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.8291555555555555
# Testing Accuracy: 0.7839374555792467
# Testing Confusion Matrix:
# [[913 149]
#  [155 190]]
# Testing Recall: 0.5507246376811594
# Testing Precesion: 0.56047197640118
# Testing F-1: 0.5555555555555557
# Testing F-Beta: 0.5584950029394474

# %%
cm= confusion_matrix(y_test, y_pred)
plt.figure(figsize =(6,5))
sns.heatmap(cm, annot=True, fmt= '.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Decision tree

# %%
from sklearn.model_selection import GridSearchCV 
params= [
    {'max_depth':[10,11,13,15,20], 'min_samples_split': [2, 3 ,4 ,5]}
    
]
grid = GridSearchCV(estimator=DecisionTreeClassifier(),
                   param_grid= params ,
                   scoring= 'accuracy' ,
                   cv= 10)
grid.fit(x_train, y_train)

print(grid.best_params_)
# Out:
# {'max_depth': 10, 'min_samples_split': 5}

# %%
DT= DecisionTreeClassifier(max_depth=10, min_samples_split=5)

DT.fit(x_train, y_train)
y_pred = DT.predict(x_test)
print(f'Training Accuracy: {DT.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.8663111111111111
# Testing Accuracy: 0.7867803837953091
# Testing Confusion Matrix:
# [[927 135]
#  [165 180]]
# Testing Recall: 0.5217391304347826
# Testing Precesion: 0.5714285714285714
# Testing F-1: 0.5454545454545454
# Testing F-Beta: 0.5607476635514017

# %%
cm= confusion_matrix(y_test, y_pred)
plt.figure(figsize =(6,5))
sns.heatmap(cm, annot=True, fmt= '.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Random Forest

# %%
#Hyperparameter tuning 

from sklearn.model_selection import GridSearchCV 
params= [
    {'max_depth':[5,10,11,13,15], 'min_samples_split': [2, 3 ,4 ,5],
    'n_estimators':[50,100,150,200]}
    
]
grid = GridSearchCV(estimator=RandomForestClassifier(),
                   param_grid= params ,
                   scoring= 'accuracy' ,
                   cv= 10)
grid.fit(x_train, y_train)

print(grid.best_params_)
# Out:
# {'max_depth': 11, 'min_samples_split': 2, 'n_estimators': 200}

# %%
RF= RandomForestClassifier(n_estimators=200, max_depth= 11)

RF.fit(x_train, y_train)
y_pred = RF.predict(x_test)
print(f'Training Accuracy: {RF.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.9104
# Testing Accuracy: 0.8166311300639659
# Testing Confusion Matrix:
# [[964  98]
#  [160 185]]
# Testing Recall: 0.5362318840579711
# Testing Precesion: 0.6537102473498233
# Testing F-1: 0.5891719745222931
# Testing F-Beta: 0.6262694651320245

# %%
cm= confusion_matrix(y_test, y_pred)
plt.figure(figsize =(6,5))
sns.heatmap(cm, annot=True, fmt= '.1f')
# Out:
# <AxesSubplot:>

# %%
RF= RandomForestClassifier(n_estimators=200, max_depth= 11, min_samples_split= 2)

RF.fit(x_train, y_train)
y_pred = RF.predict(x_test)
print(f'Training Accuracy: {RF.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.9054222222222222
# Testing Accuracy: 0.8237384506041222
# Testing Confusion Matrix:
# [[966  96]
#  [152 193]]
# Testing Recall: 0.5594202898550724
# Testing Precesion: 0.6678200692041523
# Testing F-1: 0.6088328075709779
# Testing F-Beta: 0.64290473017988

# %%
from sklearn.model_selection import cross_validate


RF= RandomForestClassifier(n_estimators=200, max_depth=11, min_samples_split=2)
cv= cross_validate(RF, x, y, cv=10 , return_train_score= True)
RF.fit(x_train, y_train)
y_pred = RF.predict(x_test)
print(f'Training Accuracy: {RF.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.9086222222222222
# Testing Accuracy: 0.814498933901919
# Testing Confusion Matrix:
# [[963  99]
#  [162 183]]
# Testing Recall: 0.5304347826086957
# Testing Precesion: 0.648936170212766
# Testing F-1: 0.583732057416268
# Testing F-Beta: 0.6211812627291242

# %% [markdown]
# # SVM

# %%
#Hyperparameter tuning 

from sklearn.model_selection import GridSearchCV 
params= [
    {'kernel':['linear','rbf','poly'], 'C':[1, 2 ,3,4,5], 'degree':[3,4,5]}
    
]
grid = GridSearchCV(estimator=SVC(),
                   param_grid= params ,
                   scoring= 'accuracy' ,
                   cv= 10)
grid.fit(x_train, y_train)

print(grid.best_params_)
# Out:
# {'C': 1, 'degree': 3, 'kernel': 'linear'}

# %%
svc= SVC(C=1, kernel= 'linear', degree= 3)

svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
print(f'Training Accuracy: {svc.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.7950222222222222
# Testing Accuracy: 0.8109452736318408
# Testing Confusion Matrix:
# [[954 108]
#  [158 187]]
# Testing Recall: 0.5420289855072464
# Testing Precesion: 0.6338983050847458
# Testing F-1: 0.584375
# Testing F-Beta: 0.6131147540983607

# %% [markdown]
# # XGBOOST

# %%
#Hyperparameter tuning 

from sklearn.model_selection import GridSearchCV 
params= [
    {'n_estimators':[50,100,150,200], 'max_depth':[5,6,7,10,11,15], 'learning_rate':[0.1,0.2,0.4,0.7]}
]
grid = GridSearchCV(estimator=XGBClassifier(),
                   param_grid= params ,
                   scoring= 'accuracy' ,
                   cv= 10)
grid.fit(x_train, y_train)

print(grid.best_params_)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
XGB_Model= XGBClassifier(max_depth= 5, n_estimators=50, learning_rate=0.1)

XGB_Model.fit(x_train, y_train)
y_pred = XGB_Model.predict(x_test)
print(f'Training Accuracy: {XGB_Model.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')



print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:11:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training Accuracy: 0.8300444444444445
# Testing Accuracy: 0.8230277185501066
# Testing Confusion Matrix:
# [[970  92]
#  [157 188]]
# Testing Recall: 0.5449275362318841
# Testing Precesion: 0.6714285714285714
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89      1062
#            1       0.67      0.54      0.60       345
#
#     accuracy                           0.82      1407
#    macro avg       0.77      0.73      0.74      1407
# weighted avg       0.81      0.82      0.82      1407

# %%
from sklearn.model_selection import cross_validate


XGBoot= XGBClassifier(max_depth= 5, n_estimators=50, learning_rate=0.1)
cv= cross_validate(XGBoot, x, y, cv=10 , return_train_score= True)
XGBoot.fit(x_train, y_train)
y_pred = XGBoot.predict(x_test)
print(f'Training Accuracy: {XGBoot.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:12:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# # Logesric Regression

# %%
LR= LogisticRegression()
LR.fit(x_train, y_train)
y_pred = LR.predict(x_test)
print(f'Training Accuracy: {LR.score(x_train, y_train)}')
print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
print(f'Testing F-1: {f1_score(y_test, y_pred)}')
print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
# Out:
# Training Accuracy: 0.8019555555555555
# Testing Accuracy: 0.8230277185501066
# Testing Confusion Matrix:
# [[956 106]
#  [143 202]]
# Testing Recall: 0.5855072463768116
# Testing Precesion: 0.6558441558441559
# Testing F-1: 0.6186830015313937
# Testing F-Beta: 0.6404565630944832

# %%
models = {
    "LR": LogisticRegression(),
    "KNN": KNeighborsClassifier(n_neighbors= 5),
    "SVC": SVC(kernel='linear'),
    "DT": DecisionTreeClassifier(max_depth=10, min_samples_split=5),
    "RF": RandomForestClassifier(n_estimators=100, max_depth= 10, min_samples_split= 3),
    "XGB": XGBClassifier(max_depth= 5, n_estimators=50, learning_rate=0.1),
    "Naive Bayes": GaussianNB()
}
for name, model in models.items():
    print(f'Training Model {name} \n--------------')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Training Accuracy: {model.score(x_train, y_train)}')
    print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
    print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
    print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
    print(f'Testing F-1: {f1_score(y_test, y_pred)}')
    print(f'Testing F-Beta: {fbeta_score(y_test, y_pred, beta=0.5)}')
    print('-'*30)
# Out:
# Training Model LR
# --------------
# Training Accuracy: 0.8019555555555555
# Testing Accuracy: 0.8230277185501066
# Testing Confusion Matrix:
# [[956 106]
#  [143 202]]
# Testing Recall: 0.5855072463768116
# Testing Precesion: 0.6558441558441559
# Testing F-1: 0.6186830015313937
# Testing F-Beta: 0.6404565630944832
# ------------------------------
# Training Model KNN
# --------------
# Training Accuracy: 0.8291555555555555
# Testing Accuracy: 0.7839374555792467
# Testing Confusion Matrix:
# [[913 149]
#  [155 190]]
# Testing Recall: 0.5507246376811594
# Testing Precesion: 0.56047197640118
# Testing F-1: 0.5555555555555557
# Testing F-Beta: 0.5584950029394474
# ------------------------------
# Training Model SVC
# --------------
# Training Accuracy: 0.7950222222222222
# Testing Accuracy: 0.8109452736318408
# Testing Confusion Matrix:
# [[954 108]
#  [158 187]]
# Testing Recall: 0.5420289855072464
# Testing Precesion: 0.6338983050847458
# Testing F-1: 0.584375
# ...

# %%
import joblib

# %%
joblib.dump(XGB_Model, 'model.h5')
# Out:
# ['model.h5']

# %%
joblib.dump(scaler, 'scaler.h5')
# Out:
# ['scaler.h5']

# %%
x.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No',
# ...
